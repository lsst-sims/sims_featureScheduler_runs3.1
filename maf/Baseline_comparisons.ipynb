# %% [markdown]
# Let's look at variations across the different baseline runs

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import pandas as pd
import os

from matplotlib.legend_handler import HandlerErrorbar

# %%
# download summary file if needed
if not os.path.isfile('summary.h5'):
    import requests
    url = 'https://s3df.slac.stanford.edu/data/rubin/sim-data/sims_featureScheduler_runs3.1/maf/summary.h5'
    r = requests.get(url)
    open('summary.h5', 'wb').write(r.content)

data_loaded = pd.read_hdf('summary.h5')
data_loaded.shape
# Out:
# (46, 42385)

# %%
# Only the runs we are interested in, in proper chonological release order
times = ['retro_baseline_v2.0_10yrs', 'baseline_v2.0_10yrs', 'baseline_v2.1_10yrs', 'baseline_v2.2_10yrs',
        'baseline_v3.0_10yrs', 'starter_v3.1_10yrs'] 
data_loaded = data_loaded.reindex(labels=times)

# %%
#[col for col in data_loaded.columns if 'Number of Exposures' in col]

# %%
# Pull out the metrics we are interested in and define simple names

name_dict = {'best18k parallax HealpixSlicer': 'parallax best 18k',
            'best18k properMotion HealpixSlicer': 'proper motion best 18k',
            'Fraction detected of total (mean) MicrolensingMetric_detect tE 20_30 days UserPointsSlicer': '20-30d microlensing\ndetection',
            'Fraction detected of total (mean) MicrolensingMetric_detect tE 60_90 days UserPointsSlicer': '60-90d microlensing\ndetection',
            'fONv MedianNvis fO HealpixSlicer': 'fO N vis',
             'Identity Number of Exposures UniSlicer': 'Total N visits',
            'Total detected SNNSNMetric_reducen_sn DDF excluded HealpixSlicer': 'SNe, N',
             'Median SNNSNMetric_reducezlim DDF excluded HealpixSlicer': 'SNe, zlim',
            '3x2ptFoM Exgalm5WithCuts i band non-DD year 10 HealpixSlicer': '3x2 i-band',
            'Median WeakLensingNvisits gri band non-DD HealpixSlicer': 'WL Nvis \ni-band',
            'Total detected KNePopMetric_single_ztfrest_simple single model UserPointsSlicer': 'KNe single model',
            'Total detected XRBPopMetric_early_detect UserPointsSlicer': 'XRB\nearly detect',
            'VolumeSum Brown Dwarf, L7 HealpixSlicer': 'Brown Dwarf Vol',
            'CumulativeCompleteness H <= 16.000000 DiscoveryNChances NEO 3 pairs in 15 nights SNR=3 detection loss MoObjSlicer': 'NEO bright',
            'CumulativeCompleteness H <= 22.000000 DiscoveryNChances NEO 3 pairs in 15 nights SNR=3 detection loss MoObjSlicer': 'NEO faint',
            'CumulativeCompleteness H <= 6.000000 DiscoveryNChances TNO 3 pairs in 15 nights SNR=3 detection loss MoObjSlicer': 'TNO',
            'CumulativeCompleteness H <= 20.000000 DiscoveryNChances MBA 3 pairs in 15 nights SNR=3 detection loss MoObjSlicer': 'MBA',
            'CumulativeCompleteness H <= 18.000000 DiscoveryNChances Trojan 3 pairs in 15 nights SNR=3 detection loss MoObjSlicer': 'Trojan',

            'CumulativeCompleteness H <= 16.000000 DiscoveryNChances Vatira 1 quad in 1 night detection loss MoObjSlicer': 'Vatira'}

# drop in the units for the columns
units = {'parallax best 18k': 'mas',
         'proper motion best 18k': 'mas/yr',
         '20-30d microlensing\ndetection': 'fraction', 
         '60-90d microlensing\ndetection': 'fraction', 
         'fO N vis' : '',
         'Total N visits': '',
         'SNe, N': '', 
         'SNe, zlim': '', 
         '3x2 i-band': 'score', 
         'WL Nvis \ni-band': '', 
         'KNe ZTF simple': 'N', 
         'KNe single model': 'N',
         'XRB\nearly detect': 'N', 
         'Brown Dwarf Vol': 'pc^3', 
         'NEO bright': 'fraction', 
         'NEO faint': 'fraction', 
         'TNO': 'fraction', 
         'MBA':'fraction',
         'Trojan': 'fraction',
         'Vatira': 'fraction',
        }

# If columns are uncertainties, we want to plot them backwards
invert_cols = ['parallax best 18k', 'proper motion best 18k']


data = pd.DataFrame()
for key in name_dict:
    data[name_dict[key]] = data_loaded[key]
    

mag_dict = {'Median CoaddM5 g HealpixSlicer': 'Median g',
 'Median CoaddM5 i HealpixSlicer': 'Median i',
 'Median CoaddM5 r HealpixSlicer': 'Median r',
 'Median CoaddM5 u HealpixSlicer': 'Median u',
 'Median CoaddM5 y HealpixSlicer': 'Median y',
 'Median CoaddM5 z HealpixSlicer': 'Median z'}

mag_data = pd.DataFrame()
for key in mag_dict:
    mag_data[mag_dict[key]] = data_loaded[key]
    
    
    
ddf_dict = {'Sum SNNSNMetric DD:COSMOS_reducen_sn DD:COSMOS all bands, only DDF observations HealpixSubsetSlicer' : 'N SN COSMOS',
           'Sum SNNSNMetric DD:ECDFS_reducen_sn DD:ECDFS all bands, only DDF observations HealpixSubsetSlicer' : 'N SN ECDFS',
           'Sum SNNSNMetric DD:EDFS_reducen_sn DD:EDFS all bands, only DDF observations HealpixSubsetSlicer' : 'N SN EDFS',
           'Sum SNNSNMetric DD:ELAISS1_reducen_sn DD:ELAISS1 all bands, only DDF observations HealpixSubsetSlicer' : 'N SN ELAISS1',
           'Sum SNNSNMetric DD:XMM_LSS_reducen_sn DD:XMM_LSS all bands, only DDF observations HealpixSubsetSlicer' : 'N SN XMM_LSS',
            
           'Median SNNSNMetric DD:COSMOS_reducezlim DD:COSMOS all bands, only DDF observations HealpixSubsetSlicer': 'zlim COSMOS',
            'Median SNNSNMetric DD:ECDFS_reducezlim DD:ECDFS all bands, only DDF observations HealpixSubsetSlicer': 'zlim ECDFS',
            'Median SNNSNMetric DD:EDFS_reducezlim DD:EDFS all bands, only DDF observations HealpixSubsetSlicer': 'zlim EDFS',
            'Median SNNSNMetric DD:ELAISS1_reducezlim DD:ELAISS1 all bands, only DDF observations HealpixSubsetSlicer': 'zlim ELAISS1',
            'Median SNNSNMetric DD:XMM_LSS_reducezlim DD:XMM_LSS all bands, only DDF observations HealpixSubsetSlicer': 'zlim XMM_LSS',
            
           }

ddf_data = pd.DataFrame()
for key in ddf_dict:
    ddf_data[ddf_dict[key]] = data_loaded[key]

# %%
# here's my way of searching through to find the right column name. Say you wanted to find a TDE metric to add
[col for col in data_loaded.columns if 'TDE' in col]
# Out:
# ['Fraction detected in footprint (mean) TDE_Quality_some_color_pnum UserPointsSlicer',
#  'Fraction detected in footprint (mean) TDE_Quality_some_color_pu_pnum UserPointsSlicer',
#  'Fraction detected in footprint (mean) TDEsPopMetric_prepeak UserPointsSlicer',
#  'Fraction detected in footprint (mean) TDEsPopMetric_some_color UserPointsSlicer',
#  'Fraction detected in footprint (mean) TDEsPopMetric_some_color_pu UserPointsSlicer',
#  'Fraction detected of total (mean) TDE_Quality_some_color_pnum UserPointsSlicer',
#  'Fraction detected of total (mean) TDE_Quality_some_color_pu_pnum UserPointsSlicer',
#  'Fraction detected of total (mean) TDEsPopMetric_prepeak UserPointsSlicer',
#  'Fraction detected of total (mean) TDEsPopMetric_some_color UserPointsSlicer',
#  'Fraction detected of total (mean) TDEsPopMetric_some_color_pu UserPointsSlicer',
#  'Total detected TDE_Quality_some_color_pnum UserPointsSlicer',
#  'Total detected TDE_Quality_some_color_pu_pnum UserPointsSlicer',
#  'Total detected TDEsPopMetric_prepeak UserPointsSlicer',
#  'Total detected TDEsPopMetric_some_color UserPointsSlicer',
#  'Total detected TDEsPopMetric_some_color_pu UserPointsSlicer',
#  'Total lightcurves in footprint TDE_Quality_some_color_pnum UserPointsSlicer',
#  'Total lightcurves in footprint TDE_Quality_some_color_pu_pnum UserPointsSlicer',
#  'Total lightcurves in footprint TDEsPopMetric_prepeak UserPointsSlicer',
#  'Total lightcurves in footprint TDEsPopMetric_some_color UserPointsSlicer',
#  'Total lightcurves in footprint TDEsPopMetric_some_color_pu UserPointsSlicer',
#  'Total lightcurves on sky TDE_Quality_some_color_pnum UserPointsSlicer',
#  'Total lightcurves on sky TDE_Quality_some_color_pu_pnum UserPointsSlicer',
#  'Total lightcurves on sky TDEsPopMetric_prepeak UserPointsSlicer',
#  'Total lightcurves on sky TDEsPopMetric_some_color UserPointsSlicer',
#  'Total lightcurves on sky TDEsPopMetric_some_color_pu UserPointsSlicer']

# %%
# A selection of my favorite metrics
data
# Out:
#                            parallax best 18k  proper motion best 18k
# retro_baseline_v2.0_10yrs           0.804328                0.176701  \
# baseline_v2.0_10yrs                 0.791058                0.184088
# baseline_v2.1_10yrs                 0.806910                0.188258
# baseline_v2.2_10yrs                 0.792958                0.186345
# baseline_v3.0_10yrs                 0.792666                0.185683
# starter_v3.1_10yrs                  0.802899                0.187499
#
#                            20-30d microlensing\ndetection
# retro_baseline_v2.0_10yrs                          0.0883  \
# baseline_v2.0_10yrs                                0.3116
# baseline_v2.1_10yrs                                0.3111
# baseline_v2.2_10yrs                                0.3212
# baseline_v3.0_10yrs                                0.3239
# starter_v3.1_10yrs                                 0.3346
#
#                            60-90d microlensing\ndetection  fO N vis
# retro_baseline_v2.0_10yrs                          0.1533     848.0  \
# baseline_v2.0_10yrs                                0.4284     839.0
# baseline_v2.1_10yrs                                0.4312     838.0
# baseline_v2.2_10yrs                                0.4462     830.0
# baseline_v3.0_10yrs                                0.4559     795.0
# starter_v3.1_10yrs                                 0.4664     795.0
#
#                            Total N visits         SNe, N  SNe, zlim
# retro_baseline_v2.0_10yrs       2048566.0   97124.012102   0.281304  \
# baseline_v2.0_10yrs             2086980.0   99302.532220   0.282012
# baseline_v2.1_10yrs             2081749.0   99294.339899   0.283756
# baseline_v2.2_10yrs             2074975.0  112802.099640   0.289980
# baseline_v3.0_10yrs             2086079.0  109475.798536   0.293926
# starter_v3.1_10yrs              2106023.0  118003.590290   0.301420
#
#                            3x2 i-band  WL Nvis \ni-band  KNe single model
# retro_baseline_v2.0_10yrs   34.632263             449.0            3982.0  \
# baseline_v2.0_10yrs         37.908126             443.0            4544.0
# baseline_v2.1_10yrs         38.560143             443.0            4777.0
# baseline_v2.2_10yrs         39.794283             440.0            5215.0
# baseline_v3.0_10yrs         38.643260             423.0            5654.0
# starter_v3.1_10yrs          39.019244             422.0            5363.0
#
#                            XRB\nearly detect  Brown Dwarf Vol  NEO bright
# retro_baseline_v2.0_10yrs              720.0    179640.718155      0.9048  \
# baseline_v2.0_10yrs                   1879.0    168086.074111      0.9294
# baseline_v2.1_10yrs                   1918.0    163815.013503      0.9286
# baseline_v2.2_10yrs                   1920.0    172453.127988      0.9304
# baseline_v3.0_10yrs                   1950.0    168032.537231      0.9326
# starter_v3.1_10yrs                    2049.0    171619.716167      0.9288
#
#                            NEO faint       TNO       MBA    Trojan  Vatira
# retro_baseline_v2.0_10yrs   0.623933  0.705953  0.943433  0.667158     NaN
# baseline_v2.0_10yrs         0.642021  0.719635  0.918999  0.588087  0.0039
# baseline_v2.1_10yrs         0.647553  0.723197  0.927567  0.608979  0.0017
# baseline_v2.2_10yrs         0.657476  0.723913  0.933507  0.615265  0.0008
# baseline_v3.0_10yrs         0.642155  0.722293  0.924185  0.611053  0.0376
# starter_v3.1_10yrs          0.640267  0.721860  0.929189  0.603105  0.0471

# %%
# Median depths in each filter
mag_data
# Out:
#                             Median g   Median i   Median r   Median u
# retro_baseline_v2.0_10yrs  26.835006  26.308518  26.850968  25.707301  \
# baseline_v2.0_10yrs        26.733479  26.218659  26.755971  25.818916
# baseline_v2.1_10yrs        26.736248  26.252054  26.781543  25.751969
# baseline_v2.2_10yrs        26.753646  26.290929  26.835430  25.724699
# baseline_v3.0_10yrs        26.688123  26.264600  26.818287  25.668262
# starter_v3.1_10yrs         26.702741  26.275374  26.811500  25.679105
#
#                             Median y   Median z
# retro_baseline_v2.0_10yrs  24.842363  25.606168
# baseline_v2.0_10yrs        24.762720  25.510379
# baseline_v2.1_10yrs        24.728145  25.486640
# baseline_v2.2_10yrs        24.782743  25.581317
# baseline_v3.0_10yrs        24.756955  25.524781
# starter_v3.1_10yrs         24.771007  25.561028

# %%
# SNe performance in each DDF for each run
ddf_data
# Out:
#                            N SN COSMOS  N SN ECDFS   N SN EDFS  N SN ELAISS1
# retro_baseline_v2.0_10yrs    25.032699    2.192431         NaN     66.749298  \
# baseline_v2.0_10yrs          47.333916    5.217382         NaN     81.438800
# baseline_v2.1_10yrs          21.899369    2.592571         NaN     40.212476
# baseline_v2.2_10yrs          13.647867    6.881372         NaN      3.753806
# baseline_v3.0_10yrs         362.726856   72.383449   74.734786     37.378088
# starter_v3.1_10yrs          569.390177  324.557076  696.511503    299.499915
#
#                            N SN XMM_LSS  zlim COSMOS  zlim ECDFS  zlim EDFS
# retro_baseline_v2.0_10yrs     69.111051     0.589623    0.519676        NaN  \
# baseline_v2.0_10yrs           72.445437     0.596891    0.543027        NaN
# baseline_v2.1_10yrs           32.838014     0.594427    0.545216        NaN
# baseline_v2.2_10yrs                 NaN     0.514987    0.577431        NaN
# baseline_v3.0_10yrs           60.363667     0.594675    0.575080   0.526724
# starter_v3.1_10yrs           319.197748     0.573324    0.585288   0.527892
#
#                            zlim ELAISS1  zlim XMM_LSS
# retro_baseline_v2.0_10yrs      0.570611      0.570498
# baseline_v2.0_10yrs            0.593426      0.562289
# baseline_v2.1_10yrs            0.594464      0.561932
# baseline_v2.2_10yrs            0.600156           NaN
# baseline_v3.0_10yrs            0.546128      0.539335
# starter_v3.1_10yrs             0.574021      0.564239

# %%
# now to load up runs where the weather was varied to generate some rough error bars
data_loaded = pd.read_hdf('summary.h5')
runs = [run for run in data_loaded.index if 'weather' in run]
weather_data = data_loaded.reindex(labels=runs)
std_dict = {}
for key in name_dict:
    std_dict[name_dict[key]] = np.std(weather_data[key].values)
for key in mag_dict:
    std_dict[mag_dict[key]] = np.std(weather_data[key].values)
for key in ddf_dict:
    std_dict[ddf_dict[key]] = np.std(weather_data[key].values)

# %%
for col in data.columns:
    fig, ax = plt.subplots()
    ax.plot(data[col], 'ko')
    label_add = ''
    h0 = ax.errorbar(np.arange(data[col].values.size), data[col], yerr=std_dict[col], fmt='s', color='k',
               label=r'1-$\sigma$ weather'
                '\n variation', marker='o')
    if units[col] != '':
        label_add = ' (' + units[col]+')'
    ax.set_ylabel(col + label_add)
    ax.tick_params(axis='x', labelrotation = 90)
    hh=[h0]
    ax.legend(hh, [H.get_label() for H in hh],
        handler_map={type(h0): HandlerErrorbar(xerr_size=1)})
    if col in invert_cols:
        ax.set_ylim(ax.get_ylim()[::-1])
# Out:
# /var/folders/jv/jdhmc2t93njct5cx375mztcr0000gn/T/ipykernel_13766/915796823.py:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s" (-> marker='s'). The keyword argument will take precedence.
#   h0 = ax.errorbar(np.arange(data[col].values.size), data[col], yerr=std_dict[col], fmt='s', color='k',
# /Users/yoachim/anaconda3/envs/rubin2/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1185: RuntimeWarning: All-NaN axis encountered
#   miny = np.nanmin(masked_verts[..., 1])
# /Users/yoachim/anaconda3/envs/rubin2/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1186: RuntimeWarning: All-NaN axis encountered
#   maxy = np.nanmax(masked_verts[..., 1])

# %%
data = mag_data
for col in data.columns:
    fig, ax = plt.subplots()
    ax.plot(data[col], 'ko')
    label_add = ''
    h0 = ax.errorbar(np.arange(data[col].values.size), data[col], yerr=std_dict[col], fmt='s', color='k',
               label=r'1-$\sigma$ weather'
                '\n variation', marker='o')
    
    label_add = ' (mag)'
    ax.set_ylabel(col + label_add)
    ax.tick_params(axis='x', labelrotation = 90)
    hh=[h0]
    ax.legend(hh, [H.get_label() for H in hh],
        handler_map={type(h0): HandlerErrorbar(xerr_size=1)})
    if col in invert_cols:
        ax.set_ylim(ax.get_ylim()[::-1])
# Out:
# /var/folders/jv/jdhmc2t93njct5cx375mztcr0000gn/T/ipykernel_13766/327149632.py:6: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s" (-> marker='s'). The keyword argument will take precedence.
#   h0 = ax.errorbar(np.arange(data[col].values.size), data[col], yerr=std_dict[col], fmt='s', color='k',

# %%
data = ddf_data
for col in data.columns:
    fig, ax = plt.subplots()
    ax.plot(data[col], 'ko')
    label_add = ''
    h0 = ax.errorbar(np.arange(data[col].values.size), data[col], yerr=std_dict[col], fmt='s', color='k',
               label=r'1-$\sigma$ weather'
                '\n variation', marker='o')
    
    label_add = ' '
    ax.set_ylabel(col + label_add)
    ax.tick_params(axis='x', labelrotation = 90)
    hh=[h0]
    ax.legend(hh, [H.get_label() for H in hh],
        handler_map={type(h0): HandlerErrorbar(xerr_size=1)})
    if col in invert_cols:
        ax.set_ylim(ax.get_ylim()[::-1])
# Out:
# /var/folders/jv/jdhmc2t93njct5cx375mztcr0000gn/T/ipykernel_13766/3313841272.py:6: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s" (-> marker='s'). The keyword argument will take precedence.
#   h0 = ax.errorbar(np.arange(data[col].values.size), data[col], yerr=std_dict[col], fmt='s', color='k',

# %% [markdown]
# Some major changes of note:
#
# * v2.0 and 3.0 both had substantial changes in the survey footprint, with 2.0 introducing more coverage of the bulge and 3.0 having expanded coverage in the Galactic plane
# * v3.0 introduced high airmass twilight observations that drastically increase detection of Vatira solar system objects
# * v3.0 introduced observing the COSMOS DDF to full depth in the first ~3 years
# * starter_v3.1 introduced sometimes leaving the z filter loaded (and removing y) in dark time. Before u was always swapped with z. This prevents long gaps in z-coverage which gives a large boost to SNe in DDFs
