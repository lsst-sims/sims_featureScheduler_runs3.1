# %%
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
from no_plane import  NoPlaneFootprint
import numpy as np

# %%
nside=32
sky = NoPlaneFootprint(nside=nside, smc_radius=4, lmc_radius=6)
footprints_hp_array, labels = sky.return_maps()

# %%
hp.mollview(footprints_hp_array["r"])

# %%
np.unique(footprints_hp_array["r"])
# Out:
# array([0.  , 0.1 , 0.4 , 1.  , 1.05])

# %%
from light_plane import NoPlaneFootprint
sky = NoPlaneFootprint(nside=nside, smc_radius=4, lmc_radius=6)
footprints_hp_array, labels = sky.return_maps()
hp.mollview(footprints_hp_array["r"])

# %%
np.unique(footprints_hp_array["r"])
# Out:
# array([0.  , 0.01, 0.1 , 0.4 , 1.  , 1.05])

# %%
from heavy_plane import NoPlaneFootprint
sky = NoPlaneFootprint(nside=nside, smc_radius=4, lmc_radius=6)
footprints_hp_array, labels = sky.return_maps()
hp.mollview(footprints_hp_array["r"])
hp.graticule()

# %%
np.unique(footprints_hp_array["r"])
# Out:
# array([0.  , 0.1 , 0.4 , 1.  , 1.05])
