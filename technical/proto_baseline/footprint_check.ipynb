# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
from proto_baseline import EuclidOverlapFootprint as gf
from rubin_sim.utils import hpid2_ra_dec, angular_separation

# %%
agg_level = 1.5
nside = 128

sky = gf(nside=nside, smc_radius=4, lmc_radius=6)
footprints_hp_array, labels = sky.return_maps()

# %%
for key in footprints_hp_array.dtype.names:
    hp.mollview(footprints_hp_array[key], title=key)
    hp.graticule()

# %%
np.unique(footprints_hp_array[key])
# Out:
# array([0.  , 0.1 , 0.22, 0.65, 0.9 ])

# %%
gp_pix = np.where(footprints_hp_array[key] == 0.65)[0]

# %%
gp_pix
# Out:
# array([ 79247,  79249,  79513, ..., 188182, 188184, 188186])
